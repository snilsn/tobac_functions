# %% [markdown]
# # Plotting.py functions

# %%
import tobac
import tobac.testing

# %% [markdown]
# ## plot_mask_cell_track_follow
# broken?
# Entries of track['time_cell'] are already timedeltas.

# %%
# %%capture

data = tobac.testing.make_sample_data_2D_3blobs_inv()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data, dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
tobac.plot_mask_cell_track_follow(1, track, None, features, mask, None, None)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:617: UserWarning: When using tobac plotting functions that render a figure, you may need to set the Matplotlib backend to 'agg' by `matplotlib.use('agg').
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 tobac.plot_mask_cell_track_follow(1, track, None, features, mask, None, None)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:675, in plot_mask_cell_track_follow(cell, track, cog, features, mask_total, field_contour, field_filled, width, name, plotdir, file_format, figsize, dpi, **kwargs)
#     671 fig1.subplots_adjust(left=0.2, bottom=0.15, right=0.85, top=0.80)
#     673 datestring_stamp = row["time"].strftime("%Y-%m-%d %H:%M:%S")
#     674 celltime_stamp = "%02d:%02d:%02d" % (
# --> 675     row["time_cell"].dt.total_seconds() // 3600,
#     676     (row["time_cell"].dt.total_seconds() % 3600) // 60,
#     677     row["time_cell"].dt.total_seconds() % 60,
#     678 )
#     679 title = datestring_stamp + " , " + celltime_stamp
#     680 datestring_file = row["time"].strftime("%Y-%m-%d_%H%M%S")
#
# AttributeError: 'Timedelta' object has no attribute 'dt'

# %%
track['time_cell'][0]
# Out:
# Timedelta('0 days 00:00:00')

# %% [markdown]
# ## plot_mask_cell_individual_follow
# broken?
# Applying .item() to an array with size > 1

# %%
import cartopy
import matplotlib.pyplot as plt
import numpy as np
n = 40
# %matplotlib inline
fig, geo_axes = plt.subplots(
            ncols=1,
            nrows=1,
            figsize=(10, 10),
            subplot_kw={"projection": cartopy.crs.PlateCarree()},
        )

tobac.plotting.plot_mask_cell_individual_follow(1, track, track, features, mask, None, None, axes=geo_axes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 13>()
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       6 fig, geo_axes = plt.subplots(
#       7             ncols=1,
#       8             nrows=1,
#       9             figsize=(10, 10),
#      10             subplot_kw={"projection": cartopy.crs.PlateCarree()},
#      11         )
# ---> 13 tobac.plotting.plot_mask_cell_individual_follow(1, track, track, features, mask, None, None, axes=geo_axes)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:756, in plot_mask_cell_individual_follow(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, width, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title)
#     752 from matplotlib.colors import Normalize
#     754 divider = make_axes_locatable(axes)
# --> 756 x_pos = track[track["cell"] == cell_i]["projection_x_coordinate"].item()
#     757 y_pos = track[track["cell"] == cell_i]["projection_y_coordinate"].item()
#     758 if field_filled is not None:
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/pandas/core/base.py:349, in IndexOpsMixin.item(self)
#     347 if len(self) == 1:
#     348     return next(iter(self))
# --> 349 raise ValueError("can only convert an array of size 1 to a Python scalar")
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
track[track["cell"] == 1]["projection_x_coordinate"].item()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 track[track["cell"] == 1]["projection_x_coordinate"].item()
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/pandas/core/base.py:349, in IndexOpsMixin.item(self)
#     347 if len(self) == 1:
#     348     return next(iter(self))
# --> 349 raise ValueError("can only convert an array of size 1 to a Python scalar")
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %% [markdown]
# ## plot_mask_cell_track_static
#
# broken?
#
# 2d: called function mask_features() has no z_coord keyword

# %%
# %%capture

data = tobac.testing.make_sample_data_2D_3blobs_inv()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data, dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
tobac.plotting.plot_mask_cell_track_static(1, track, track, features, mask, None, None)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:942: UserWarning: When using tobac plotting functions that render a figure, you may need to set the Matplotlib backend to 'agg' by `matplotlib.use('agg').
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 tobac.plotting.plot_mask_cell_track_static(1, track, track, features, mask, None, None)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1036, in plot_mask_cell_track_static(cell, track, cog, features, mask_total, field_contour, field_filled, width, n_extend, name, plotdir, file_format, figsize, dpi, **kwargs)
#    1033 title = datestring_stamp + " , " + celltime_stamp
#    1034 datestring_file = time_i.strftime("%Y-%m-%d_%H%M%S")
# -> 1036 ax1 = plot_mask_cell_individual_static(
#    1037     cell_i=cell,
#    1038     track=track_i,
#    1039     cog=cog_i,
#    1040     features=features_i,
#    1041     mask_total=mask_total_i,
#    1042     field_contour=field_contour_i,
#    1043     field_filled=field_filled_i,
#    1044     xlim=[x_min / 1000, x_max / 1000],
#    1045     ylim=[y_min / 1000, y_max / 1000],
#    1046     axes=ax1,
#    1047     title=title,
#    1048     **kwargs
#    1049 )
#    1051 out_dir = os.path.join(plotdir, name)
#    1052 os.makedirs(out_dir, exist_ok=True)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1224, in plot_mask_cell_individual_static(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number)
#    1220         mask_total_i_surface = mask_features_surface(
#    1221             mask_total, feature, masked=False, z_coord=z_coord
#    1222         )
#    1223     elif len(mask_total.shape) == 2:
# -> 1224         mask_total_i_surface = mask_features(
#    1225             mask_total, feature, masked=False, z_coord=z_coord
#    1226         )
#    1227     axes.contour(
#    1228         mask_total_i_surface.coord("projection_x_coordinate").points / 1000,
#    1229         mask_total_i_surface.coord("projection_y_coordinate").points / 1000,
#    (...)
#    1234         linewidth=1,
#    1235     )
#    1236 if cog is not None:
#
# TypeError: mask_features() got an unexpected keyword argument 'z_coord'

# %%
# %%capture

data = tobac.testing.make_sample_data_3D_3blobs()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data[:, 0], dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
mask.extract()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 mask.extract()
#
# TypeError: Cube.extract() missing 1 required positional argument: 'constraint'

# %%
tobac.plotting.plot_mask_cell_track_static(1, track, track, features, mask, None, None)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:942: UserWarning: When using tobac plotting functions that render a figure, you may need to set the Matplotlib backend to 'agg' by `matplotlib.use('agg').
#   warnings.warn(
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/utils.py:217: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   mask_i_data[~isin(mask_i.core_data(), feature_ids)] = 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 tobac.plotting.plot_mask_cell_track_static(1, track, track, features, mask, None, None)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1036, in plot_mask_cell_track_static(cell, track, cog, features, mask_total, field_contour, field_filled, width, n_extend, name, plotdir, file_format, figsize, dpi, **kwargs)
#    1033 title = datestring_stamp + " , " + celltime_stamp
#    1034 datestring_file = time_i.strftime("%Y-%m-%d_%H%M%S")
# -> 1036 ax1 = plot_mask_cell_individual_static(
#    1037     cell_i=cell,
#    1038     track=track_i,
#    1039     cog=cog_i,
#    1040     features=features_i,
#    1041     mask_total=mask_total_i,
#    1042     field_contour=field_contour_i,
#    1043     field_filled=field_filled_i,
#    1044     xlim=[x_min / 1000, x_max / 1000],
#    1045     ylim=[y_min / 1000, y_max / 1000],
#    1046     axes=ax1,
#    1047     title=title,
#    1048     **kwargs
#    1049 )
#    1051 out_dir = os.path.join(plotdir, name)
#    1052 os.makedirs(out_dir, exist_ok=True)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1220, in plot_mask_cell_individual_static(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number)
#    1218 z_coord = "model_level_number"
#    1219 if len(mask_total.shape) == 3:
# -> 1220     mask_total_i_surface = mask_features_surface(
#    1221         mask_total, feature, masked=False, z_coord=z_coord
#    1222     )
#    1223 elif len(mask_total.shape) == 2:
#    1224     mask_total_i_surface = mask_features(
#    1225         mask_total, feature, masked=False, z_coord=z_coord
#    1226     )
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/utils.py:217, in mask_features_surface(mask, feature_ids, masked, z_coord)
#     215 #     mask_i.data=[~isin(mask_i.data,feature_ids)]=0
#     216 mask_i_data = mask_i.core_data()
# --> 217 mask_i_data[~isin(mask_i.core_data(), feature_ids)] = 0
#     218 mask_i_surface = mask_i.collapsed(z_coord, MAX)
#     219 if masked:
#
# IndexError: too many indices for array: array is 3-dimensional, but 40 were indexed

# %% [markdown]
# ## plot_mask_cell_individual_static
#
# broken?
#
# 2d doesnt work since no z_coord
#
# 3d mask shape doenst match

# %%
# %%capture

data = tobac.testing.make_sample_data_3D_3blobs()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data[:, 0], dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
import cartopy
import matplotlib.pyplot as plt
n = 40
# %matplotlib inline
fig, geo_axes = plt.subplots(
            ncols=1,
            nrows=1,
            figsize=(10, 10),
            subplot_kw={"projection": cartopy.crs.PlateCarree()},
        )

tobac.plotting.plot_mask_cell_individual_static(1, track, 1, features, mask[0], None, None, axes = geo_axes)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/utils.py:217: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   mask_i_data[~isin(mask_i.core_data(), feature_ids)] = 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [62], in <cell line: 12>()
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 fig, geo_axes = plt.subplots(
#       6             ncols=1,
#       7             nrows=1,
#       8             figsize=(10, 10),
#       9             subplot_kw={"projection": cartopy.crs.PlateCarree()},
#      10         )
# ---> 12 tobac.plotting.plot_mask_cell_individual_static(1, track, 1, features, mask[0], None, None, axes = geo_axes)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1220, in plot_mask_cell_individual_static(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number)
#    1218 z_coord = "model_level_number"
#    1219 if len(mask_total.shape) == 3:
# -> 1220     mask_total_i_surface = mask_features_surface(
#    1221         mask_total, feature, masked=False, z_coord=z_coord
#    1222     )
#    1223 elif len(mask_total.shape) == 2:
#    1224     mask_total_i_surface = mask_features(
#    1225         mask_total, feature, masked=False, z_coord=z_coord
#    1226     )
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/utils.py:217, in mask_features_surface(mask, feature_ids, masked, z_coord)
#     215 #     mask_i.data=[~isin(mask_i.data,feature_ids)]=0
#     216 mask_i_data = mask_i.core_data()
# --> 217 mask_i_data[~isin(mask_i.core_data(), feature_ids)] = 0
#     218 mask_i_surface = mask_i.collapsed(z_coord, MAX)
#     219 if masked:
#
# IndexError: too many indices for array: array is 3-dimensional, but 40 were indexed

# %%
# %%capture

data = tobac.testing.make_sample_data_2D_3blobs_inv()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data, dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
import cartopy
import matplotlib.pyplot as plt
n = 40
# %matplotlib inline
fig, geo_axes = plt.subplots(
            ncols=1,
            nrows=1,
            figsize=(10, 10),
            subplot_kw={"projection": cartopy.crs.PlateCarree()},
        )


tobac.plotting.plot_mask_cell_individual_static(1, track, 1, features, mask[0], None, None, axes = geo_axes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 13>()
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 fig, geo_axes = plt.subplots(
#       6             ncols=1,
#       7             nrows=1,
#       8             figsize=(10, 10),
#       9             subplot_kw={"projection": cartopy.crs.PlateCarree()},
#      10         )
# ---> 13 tobac.plotting.plot_mask_cell_individual_static(1, track, 1, features, mask[0], None, None, axes = geo_axes)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1224, in plot_mask_cell_individual_static(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number)
#    1220         mask_total_i_surface = mask_features_surface(
#    1221             mask_total, feature, masked=False, z_coord=z_coord
#    1222         )
#    1223     elif len(mask_total.shape) == 2:
# -> 1224         mask_total_i_surface = mask_features(
#    1225             mask_total, feature, masked=False, z_coord=z_coord
#    1226         )
#    1227     axes.contour(
#    1228         mask_total_i_surface.coord("projection_x_coordinate").points / 1000,
#    1229         mask_total_i_surface.coord("projection_y_coordinate").points / 1000,
#    (...)
#    1234         linewidth=1,
#    1235     )
#    1236 if cog is not None:
#
# TypeError: mask_features() got an unexpected keyword argument 'z_coord'

# %% [markdown]
# ## plot_mask_cell_track_2D3Dstatic
#
# 2d: called function mask_features() has no z_coord keyword

# %%
tobac.plotting.plot_mask_cell_track_2D3Dstatic(1, track, track, features, mask, None, None)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1303: UserWarning: When using tobac plotting functions that render a figure, you may need to set the Matplotlib backend to 'agg' by `matplotlib.use('agg').
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 tobac.plotting.plot_mask_cell_track_2D3Dstatic(1, track, track, features, mask, None, None)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1408, in plot_mask_cell_track_2D3Dstatic(cell, track, cog, features, mask_total, field_contour, field_filled, width, n_extend, name, plotdir, file_format, figsize, dpi, ele, azim, **kwargs)
#    1405 title = datestring_stamp + " , " + celltime_stamp
#    1406 datestring_file = time_i.strftime("%Y-%m-%d_%H%M%S")
# -> 1408 ax1[0] = plot_mask_cell_individual_static(
#    1409     cell_i=cell,
#    1410     track=track_i,
#    1411     cog=cog_i,
#    1412     features=features_i,
#    1413     mask_total=mask_total_i,
#    1414     field_contour=field_contour_i,
#    1415     field_filled=field_filled_i,
#    1416     xlim=[x_min / 1000, x_max / 1000],
#    1417     ylim=[y_min / 1000, y_max / 1000],
#    1418     axes=ax1[0],
#    1419     title=title,
#    1420     **kwargs
#    1421 )
#    1423 ax1[1] = plot_mask_cell_individual_3Dstatic(
#    1424     cell_i=cell,
#    1425     track=track_i,
#    (...)
#    1437     **kwargs
#    1438 )
#    1440 out_dir = os.path.join(plotdir, name)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1224, in plot_mask_cell_individual_static(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number)
#    1220         mask_total_i_surface = mask_features_surface(
#    1221             mask_total, feature, masked=False, z_coord=z_coord
#    1222         )
#    1223     elif len(mask_total.shape) == 2:
# -> 1224         mask_total_i_surface = mask_features(
#    1225             mask_total, feature, masked=False, z_coord=z_coord
#    1226         )
#    1227     axes.contour(
#    1228         mask_total_i_surface.coord("projection_x_coordinate").points / 1000,
#    1229         mask_total_i_surface.coord("projection_y_coordinate").points / 1000,
#    (...)
#    1234         linewidth=1,
#    1235     )
#    1236 if cog is not None:
#
# TypeError: mask_features() got an unexpected keyword argument 'z_coord'

# %% [markdown]
# ## plot_mask_cell_track_3Dstatic

# %%
# %%capture

data = tobac.testing.make_sample_data_3D_3blobs()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data[:, 0], dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
tobac.plotting.plot_mask_cell_track_3Dstatic(1, track, None, features, mask, None, None)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1477: UserWarning: When using tobac plotting functions that render a figure, you may need to set the Matplotlib backend to 'agg' by `matplotlib.use('agg').
#   warnings.warn(
# ---------------------------------------------------------------------------
# CoordinateNotFoundError                   Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 tobac.plotting.plot_mask_cell_track_3Dstatic(1, track, None, features, mask, None, None)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1578, in plot_mask_cell_track_3Dstatic(cell, track, cog, features, mask_total, field_contour, field_filled, width, n_extend, name, plotdir, file_format, figsize, dpi, **kwargs)
#    1575 title = datestring_stamp + " , " + celltime_stamp
#    1576 datestring_file = time_i.strftime("%Y-%m-%d_%H%M%S")
# -> 1578 ax1 = plot_mask_cell_individual_3Dstatic(
#    1579     cell_i=cell,
#    1580     track=track_i,
#    1581     cog=cog_i,
#    1582     features=features_i,
#    1583     mask_total=mask_total_i,
#    1584     field_contour=field_contour_i,
#    1585     field_filled=field_filled_i,
#    1586     xlim=[x_min / 1000, x_max / 1000],
#    1587     ylim=[y_min / 1000, y_max / 1000],
#    1588     axes=ax1,
#    1589     title=title,
#    1590     **kwargs
#    1591 )
#    1593 out_dir = os.path.join(plotdir, name)
#    1594 os.makedirs(out_dir, exist_ok=True)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1671, in plot_mask_cell_individual_3Dstatic(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number, ele, azim)
#    1669 x = mask_total.coord("projection_x_coordinate").points
#    1670 y = mask_total.coord("projection_y_coordinate").points
# -> 1671 z = mask_total.coord("model_level_number").points
#    1673 #    z = mask_total.coord('geopotential_height').points
#    1674 zz, yy, xx = np.meshgrid(z, y, x, indexing="ij")
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/iris/cube.py:1919, in Cube.coord(self, name_or_coord, standard_name, long_name, var_name, attributes, axis, contains_dimension, dimensions, coord_system, dim_coords, mesh_coords)
#    1914     bad_name = _name or standard_name or long_name or ""
#    1915     emsg = (
#    1916         f"Expected to find exactly 1 {bad_name!r} coordinate, "
#    1917         "but found none."
#    1918     )
# -> 1919     raise iris.exceptions.CoordinateNotFoundError(emsg)
#    1921 return coords[0]
#
# CoordinateNotFoundError: "Expected to find exactly 1 'model_level_number' coordinate, but found none."

# %% [markdown]
# ## plot_mask_cell_individual_track_3Dstatic

# %%
# %%capture

data = tobac.testing.make_sample_data_3D_3blobs()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data[:, 0], dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
import cartopy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

n = 40
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(111,
                     projection='3d')

tobac.plotting.plot_mask_cell_individual_3Dstatic(1, track, None, features, mask, None, None, axes = ax)
# Out:
# ---------------------------------------------------------------------------
# CoordinateNotFoundError                   Traceback (most recent call last)
# Input In [29], in <cell line: 11>()
#       7 fig = plt.figure()
#       8 ax = fig.add_subplot(111,
#       9                      projection='3d')
# ---> 11 tobac.plotting.plot_mask_cell_individual_3Dstatic(1, track, None, features, mask, None, None, axes = ax)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1671, in plot_mask_cell_individual_3Dstatic(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number, ele, azim)
#    1669 x = mask_total.coord("projection_x_coordinate").points
#    1670 y = mask_total.coord("projection_y_coordinate").points
# -> 1671 z = mask_total.coord("model_level_number").points
#    1673 #    z = mask_total.coord('geopotential_height').points
#    1674 zz, yy, xx = np.meshgrid(z, y, x, indexing="ij")
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/iris/cube.py:1919, in Cube.coord(self, name_or_coord, standard_name, long_name, var_name, attributes, axis, contains_dimension, dimensions, coord_system, dim_coords, mesh_coords)
#    1914     bad_name = _name or standard_name or long_name or ""
#    1915     emsg = (
#    1916         f"Expected to find exactly 1 {bad_name!r} coordinate, "
#    1917         "but found none."
#    1918     )
# -> 1919     raise iris.exceptions.CoordinateNotFoundError(emsg)
#    1921 return coords[0]
#
# CoordinateNotFoundError: "Expected to find exactly 1 'model_level_number' coordinate, but found none."

# %% [markdown]
# ## plot_mask_cell_track_static_timeseries

# %%
# %%capture

data = tobac.testing.make_sample_data_3D_3blobs()
dxy, dt = tobac.utils.get_spacings(data)
features = tobac.feature_detection.feature_detection_multithreshold(data[:, 0], dxy, threshold = 1)
mask, features = tobac.segmentation.segmentation(features, data, dxy, threshold = 1)
track = tobac.tracking.linking_trackpy(features, data, dt, dxy, v_max=100)

# %%
tobac.plotting.plot_mask_cell_track_static_timeseries(1, track, track, features, mask, None, None, track_variable=track)
# Out:
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1838: UserWarning: When using tobac plotting functions that render a figure, you may need to set the Matplotlib backend to 'agg' by `matplotlib.use('agg').
#   warnings.warn(
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1858: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   track_variable_cell["time_cell"] = pd.to_timedelta(track_variable_cell["time_cell"])
# /home/nils/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/utils.py:217: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   mask_i_data[~isin(mask_i.core_data(), feature_ids)] = 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 tobac.plotting.plot_mask_cell_track_static_timeseries(1, track, track, features, mask, None, None, track_variable=track)
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1935, in plot_mask_cell_track_static_timeseries(cell, track, cog, features, mask_total, field_contour, field_filled, track_variable, variable, variable_ylabel, variable_label, variable_legend, variable_color, width, n_extend, name, plotdir, file_format, figsize, dpi, **kwargs)
#    1932 datestring_file = time_i.strftime("%Y-%m-%d_%H%M%S")
#    1934 # plot evolving timeseries of variable to second axis:
# -> 1935 ax1[0] = plot_mask_cell_individual_static(
#    1936     cell_i=cell,
#    1937     track=track_i,
#    1938     cog=cog_i,
#    1939     features=features_i,
#    1940     mask_total=mask_total_i,
#    1941     field_contour=field_contour_i,
#    1942     field_filled=field_filled_i,
#    1943     xlim=[x_min / 1000, x_max / 1000],
#    1944     ylim=[y_min / 1000, y_max / 1000],
#    1945     axes=ax1[0],
#    1946     title=title,
#    1947     **kwargs
#    1948 )
#    1950 track_variable_past = track_variable_cell[
#    1951     (track_variable_cell["time"] >= time_min)
#    1952     & (track_variable_cell["time"] <= time_i)
#    1953 ]
#    1954 track_variable_current = track_variable_cell[
#    1955     track_variable_cell["time"] == time_i
#    1956 ]
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/plotting.py:1220, in plot_mask_cell_individual_static(cell_i, track, cog, features, mask_total, field_contour, field_filled, axes, xlim, ylim, label_field_contour, cmap_field_contour, norm_field_contour, linewidths_contour, contour_labels, vmin_field_contour, vmax_field_contour, levels_field_contour, nlevels_field_contour, label_field_filled, cmap_field_filled, norm_field_filled, vmin_field_filled, vmax_field_filled, levels_field_filled, nlevels_field_filled, title, feature_number)
#    1218 z_coord = "model_level_number"
#    1219 if len(mask_total.shape) == 3:
# -> 1220     mask_total_i_surface = mask_features_surface(
#    1221         mask_total, feature, masked=False, z_coord=z_coord
#    1222     )
#    1223 elif len(mask_total.shape) == 2:
#    1224     mask_total_i_surface = mask_features(
#    1225         mask_total, feature, masked=False, z_coord=z_coord
#    1226     )
#
# File ~/anaconda3/envs/tobac/lib/python3.10/site-packages/tobac/utils.py:217, in mask_features_surface(mask, feature_ids, masked, z_coord)
#     215 #     mask_i.data=[~isin(mask_i.data,feature_ids)]=0
#     216 mask_i_data = mask_i.core_data()
# --> 217 mask_i_data[~isin(mask_i.core_data(), feature_ids)] = 0
#     218 mask_i_surface = mask_i.collapsed(z_coord, MAX)
#     219 if masked:
#
# IndexError: too many indices for array: array is 3-dimensional, but 40 were indexed
